# %% [markdown]
# # Autoware VisionPilot - Tutorials for End-to-End Models

# %% [markdown]
# ## I. Getting Started Guide

# %% [markdown]
# ### 1. Introducing Autoware VisionPilot and its End-to-End Models

# %% [markdown]
# Autoware **VisionPilot** is a production-grade, open-source highway autonomy system designed to power SAE
# Level-4+ autonomous driving. This project provides a safety-certifiable software stack optimized for
# integration by automotive OEMs and Tier-1 suppliers into passenger vehicles.
#
# Our key philosophies:
# - **End-to-End (E2E) AI Architecture**: unlike traditional modular stacks that rely on hand-coded rules, our
# VisionPilot utilizes neural networks for core component technologies. The roadmap includes a transition from
# the modular E2E to full monolithic and eventually Hybrid E2E AI for maximum safety and explainability.
# - **Mapless Operation**: the system does not require high-definition (HD) 3D maps. It mimics human driving by
# relying on real-time scene perception and standard 2D navigational (sat-nav) maps.
# - **Democratization**: all models, training pipelines, and weights are released under the Apache 2.0 license
# to ensure the technology is accessible to both researchers and commercial developers.
#
# Technology roadmap:
#
# | Version | Autonomy Level | Target Domain | AI Approach |
# |---|---|---|---|
# | Vision Pilot | Level 2+ | Highways | Component-based E2E AI |
# | Vision Pilot PRO | Level 2++ | Highway & Urban | Monolithic E2E AI |
# | Vision Drive | Level 4+ | All Roads | Hybrid E2E AI |

# %% [markdown]
# ### 2. Environment Setup

# %% [markdown]
# First, we need to clone the repository to your local environment. We will use the official repository from the
# Autoware Foundation.

# %%
# Clone Autoware VisionPilot repo
# !git clone https://github.com/autowarefoundation/autoware_vision_pilot.git

# Enter Models directory
# %cd autoware_vision_pilot/Models

# %% [markdown]
# The VisionPilot project relies on several key libraries, including **PyTorch** for model execution and
# **OpenCV** for image processing.
#
# We will use `pip` to install the required dependencies directly from the `requirements.txt` file provided in
# the `Models` directory.

# %%
# Enter new environment
# !python3 -m venv .visionpilot
# !source .visionpilot/bin/activate

# Install required dependencies
# !pip install -r requirements.txt

# Verify the installation (checking torch as a primary dependency)
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA availability: {torch.cuda.is_available()}")

# %% [markdown]
# ### 3. Download Models

# %% [markdown]
# How to download models.

# %% [markdown]
# ## II. Quick Test/Inference

# %% [markdown]
# Pre-requisites: please ensure that you have completed the Autoware Models Tutorial Getting Started Guide first.

# %% [markdown]
# ### 1. EgoLanes

# %% [markdown]
# #### a. Model Introduction

# %% [markdown]
# #### b. Image Inference

# %% [markdown]
# #### c. Video Inference

# %% [markdown]
# ### 2. AutoSpeed

# %% [markdown]
# #### a. Model Introduction

# %% [markdown]
# #### b. Image Inference

# %% [markdown]
# #### c. Video Inference

# %% [markdown]
# ### 3. SceneSeg

# %% [markdown]
# #### a. Model Introduction

# %% [markdown]
# #### b. Image Inference

# %% [markdown]
# #### c. Video Inference

# %% [markdown]
# ### 4. Scene3D

# %% [markdown]
# #### a. Model Introduction

# %% [markdown]
# #### b. Image Inference

# %% [markdown]
# #### c. Video Inference

# %% [markdown]
# ### 5. Domain Seg

# %% [markdown]
# #### a. Model Introduction

# %% [markdown]
# #### b. Image Inference

# %% [markdown]
# #### c. Video Inference

# %% [markdown]
# ## III. Model Training

# %% [markdown]
# ### 1. Model Training on New Data

# %% [markdown]
# ### 2. Building an Inference Pipeline
